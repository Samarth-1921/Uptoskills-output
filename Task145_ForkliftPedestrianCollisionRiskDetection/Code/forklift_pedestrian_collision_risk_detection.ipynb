# %% [markdown]
# # Task 145: Forklift-Pedestrian Collision Risk Detection System
#
# This notebook provides a complete Google Colab-compatible environment for executing the **Forklift-Pedestrian Collision Risk Detection System**.
#
# ### Pipeline Stages:
# 1. **Dependencies Installation**
# 2. **YOLOv8 Object Detection** (Pedestrians & vehicles/forklifts)
# 3. **Simple class-aware IoU Tracking**
# 4. **Collision Risk Evaluation**:
#    * Proximity warning & critical limits
#    * Predictive Trajectory Projections & Time-to-Collision (TTC)
#    * safety zone intrusion checks
# 5. **Annotated HUD Video Generation**
# 6. **Telemetry logs & Analytics Dashboard Plotting**

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install ultralytics opencv-python pandas matplotlib numpy

# %% [markdown]
# ## 2. Mount Google Drive (Optional)
# If you want to read custom video files from your Google Drive, mount it below. Otherwise, skip this cell.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 3. Clone Repository or Setup Workspace Paths
# Define directories for Code, Models, and Outputs.

# %%
import os
import sys

# Set base paths - adjust according to your folder structure
workspace_dir = "."
code_dir = os.path.join(workspace_dir, "Code")
models_dir = os.path.join(workspace_dir, "Models")
outputs_dir = os.path.join(workspace_dir, "Outputs")

os.makedirs(models_dir, exist_ok=True)
os.makedirs(outputs_dir, exist_ok=True)
print("Workspace directories are set up!")

# %% [markdown]
# ## 4. Execute built-in Synthetic Self-Test
# Run the detection script in `--test_mode`. This generates a synthetic video of a forklift and pedestrian walking and crossing paths, processes it, and validates the entire collision alert/dashboard logging pipeline without needing external files.

# %%
# Execute CLI script in self-test mode
# !python Code/detect.py --test_mode

# %% [markdown]
# ## 5. View Generated Dashboard & Summary Stats
# Check the analytics dashboard PNG and summary stats JSON produced during the run.

# %%
import json
from IPython.display import Image, display

# Display summary stats JSON
summary_path = os.path.join(outputs_dir, "summary_stats.json")
if os.path.exists(summary_path):
    print("Summary Statistics:")
    with open(summary_path, 'r') as f:
        print(json.dumps(json.load(f), indent=2))
else:
    print("summary_stats.json not found!")

print("\nLoading Analytics Dashboard:")
dashboard_path = os.path.join(outputs_dir, "analytics_dashboard.png")
if os.path.exists(dashboard_path):
    display(Image(filename=dashboard_path))
else:
    print("Dashboard image not found!")

# %% [markdown]
# ## 6. Run on your own custom Video
# Upload a video file to Colab or specify its path below to run detection and collision warnings using a pre-trained YOLOv8 model.

# %%
# Replace with your custom video path
custom_video_path = "Code/real_cctv_test_nearmiss.mp4"

if os.path.exists(custom_video_path):
    # Customize flags like --warning_dist, --critical_dist, --ttc_threshold, --zone as desired
    # !python Code/detect.py --video "{custom_video_path}" --warning_dist 130 --critical_dist 55
else:
    print(f"Custom video file '{custom_video_path}' not found. Please upload one to run the custom cell.")
